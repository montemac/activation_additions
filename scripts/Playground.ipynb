# %%
"""Basic demonstration of sweeps and metrics operation."""

# %%
# Imports, etc.
import pickle

import numpy as np
from functools import partial
import torch


from transformer_lens import HookedTransformer

from activation_additions import (
    logits,
    prompt_utils,
    utils,
    metrics,
    hook_utils
)

utils.enable_ipython_reload()

# Disable gradients to save memory during inference
_ = torch.set_grad_enabled(False)

from copy import deepcopy
from typing import List, Union,Dict
import pandas as pd
from transformer_lens.utils import get_act_name

# %%
# %%
# Load a model
MODEL = HookedTransformer.from_pretrained(model_name="gpt2-xl", device="cpu")
_ = MODEL.to("cuda:0")
# Out:
# Using pad_token, but it is not set yet.
# Loaded pretrained model gpt2-xl into HookedTransformer
# Moving model to device:  cuda:0

# %%
def conditional_perplexity(model,prompt_tokens,completion_tokens,ActAds=None):
    hook_fns=hook_utils.hook_fns_from_activation_additions(model, ActAds)
    metric_func=metrics.get_logprob_metric(model, q_funcs=(
                partial(hook_utils.add_hooks_from_dict, hook_fns=hook_fns),
                hook_utils.remove_and_return_hooks
            ))
    completed_tokens=torch.cat((prompt_tokens, completion_tokens), dim=1)
    metric=metric_func([completed_tokens])
    completion_logprobs=metric["logprob_actual_next_token"].array[0][-completion_tokens.shape[1]:]
    return -sum(completion_logprobs)

# %%
def completion_perplexities(model,
                            prompt_tokens,
                            wanted_completion_tokens,
                            unwanted_completion_tokens,
                            weighted_steering_prompts,
                            layer,
                            coefficient):
    ActAds =[prompt_utils.ActivationAddition(
                coeff=prompt_weighting*coefficient,
                act_name=layer,
                prompt=prompt) for prompt, prompt_weighting in weighted_steering_prompts.items()]
    perplexity_on_wanted=[conditional_perplexity(model, prompt, completion,ActAds) for prompt, completion in zip(prompt_tokens, wanted_completion_tokens)]
    perplexity_on_unwanted=[conditional_perplexity(model, prompt, completion,ActAds) for prompt, completion in zip(prompt_tokens, unwanted_completion_tokens)]


    return (perplexity_on_wanted, perplexity_on_unwanted)

# %%
def layer_coefficient_gridsearch(
    model: HookedTransformer,
    prompts: Union[str, List[str]],
    weighted_steering_prompts: Dict[str, float],
    Layer_list: List[int],
    coefficient_list: List[float],
    wanted_completions: Union[str, List[str]],
    unwanted_completions: Union[str, List[str]],
) -> pd.DataFrame:

    prompt_tokens=[model.to_tokens(prompt)for prompt in prompts]
    wanted_completion_tokens=[model.to_tokens(wanted_completion)[:, 1:] for wanted_completion in wanted_completions]
    unwanted_completion_tokens=[model.to_tokens(unwanted_completion)[:, 1:] for unwanted_completion in unwanted_completions]

    layer_data = []
    coefficient_data = []
    perplexity_wanted_data = []
    perplexity_unwanted_data = []

    for layer in Layer_list:
        for coefficient in coefficient_list:

            perplexity_on_wanted,perplexity_on_unwanted=completion_perplexities(model,
                            prompt_tokens,
                            wanted_completion_tokens,
                            unwanted_completion_tokens,
                            weighted_steering_prompts,
                            layer,
                            coefficient)
            
            # Append data for this layer and coefficient to the lists
            layer_data.extend([layer] * len(prompts))
            coefficient_data.extend([coefficient] * len(prompts))
            perplexity_wanted_data.extend(perplexity_on_wanted)
            perplexity_unwanted_data.extend(perplexity_on_unwanted)

    # Create DataFrame
    df = pd.DataFrame({
        "Layer": layer_data,
        "Coefficient": coefficient_data,
        "Perplexity (wanted)": perplexity_wanted_data,
        "Perplexity (unwanted)": perplexity_unwanted_data,
    })

    return df

# %%
grid_df=layer_coefficient_gridsearch(
    model=MODEL,
    prompts=["The Most beautyful city in the world is"],
    weighted_steering_prompts={" Rome":1," Paris":-1},
    Layer_list=list(range(6,12)),
    coefficient_list=list(range(0,10,2)),
    wanted_completions=" Rome",
    unwanted_completions=" Paris")

# %%
perplexity=conditional_perplexity(MODEL,
    MODEL.to_tokens("The only thing we have to fear is"),MODEL.to_tokens(" real fear.")[:, 1:])
perplexity
# Out:
# 9.4068883061409

# %%
ActAds =[prompt_utils.ActivationAddition(coeff=1, act_name=1,prompt="hi"),
         prompt_utils.ActivationAddition(coeff=-1, act_name=1,prompt="bye")]
hook_fns=hook_utils.hook_fns_from_activation_additions(MODEL, ActAds)
#for act_name, hook_fn in hook_fns.items():
#    MODEL.add_hook(act_name, hook_fn)

# %%
hook_fns["blocks.1.hook_resid_pre"]
# Out:
# [<function activation_additions.hook_utils.hook_fn_from_activations.<locals>.prompt_hook(resid_pre: jaxtyping.Float[Tensor, 'batch pos d_model'], hook: Optional[transformer_lens.hook_points.HookPoint] = None) -> jaxtyping.Float[Tensor, 'batch pos d_model']>,
#  <function activation_additions.hook_utils.hook_fn_from_activations.<locals>.prompt_hook(resid_pre: jaxtyping.Float[Tensor, 'batch pos d_model'], hook: Optional[transformer_lens.hook_points.HookPoint] = None) -> jaxtyping.Float[Tensor, 'batch pos d_model']>]

# %%
metric_func=metrics.get_logprob_metric(MODEL, q_funcs=(
                partial(hook_utils.add_hooks_from_dict, hook_fns=hook_fns),
                hook_utils.remove_and_return_hooks
             ))

# %%
metric_func([MODEL.to_tokens("The end.")])
# Out:
#             logprob_actual_next_token
# 0  [-2.6872368, -7.175348, -5.065762]

# %%
MODEL.remove_all_hook_fns()

# %%
ActAds =[prompt_utils.ActivationAddition(coeff=1, act_name=1,prompt="hi"),
         prompt_utils.ActivationAddition(coeff=-1, act_name=1,prompt="bye")]
hook_fns=hook_utils.hook_fns_from_activation_additions(MODEL, ActAds)

# %%
MODEL.remove_all_hook_fns()

# %%
grid_df=layer_coefficient_gridsearch(
    model=MODEL,
    prompts=["The Most beautyful city in the world is"],
    weighted_steering_prompts={" Rome":1," Paris":-1},
    Layer_list=list(range(6,12)),
    coefficient_list=list(range(0,10,2)),
    wanted_completions=" Rome",
    unwanted_completions=" Paris")

# %%
grid_df[0][2]
# Out:
# tensor([[220]], device='cuda:0')

# %%
conditional_perplexity(grid_df[0][0],grid_df[0][1],grid_df[0][2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 conditional_perplexity(grid_df[0][0],grid_df[0][1],grid_df[0][2])
#
# Cell In[3], line 4, in conditional_perplexity(model, prompt_tokens, completion_tokens)
#       2 metric_func=metrics.get_logprob_metric(model)
#       3 completed_tokens=torch.cat((prompt_tokens, completion_tokens), dim=1)
# ----> 4 metric=metric_func([completed_tokens])
#       5 completion_logprobs=metric["logprob_actual_next_token"].array[0][-completion_tokens.shape[1]:]
#       6 return -sum(completion_logprobs)
#
# File /mnt/ssd-2/mesaoptimizer/wuschel/activation_additions/activation_additions/metrics.py:186, in get_logprob_metric.<locals>.metric_func(tokens_list, show_progress, index)
#     183 values_list = []
#     184 for tokens in tqdm(tokens_list, disable=not show_progress):
#     185     # Run the forward call on the (p) model
# --> 186     logits = forward_with_funcs(
#     187         model, p_funcs, input=tokens, return_type="logits"
#     188     )
#     189     values = {}
#     190     if "actual_next_token" in agg_mode:
#     191         # Logprob of the next token is just the negative of the
#     192         # cross entropy loss
#
# File /mnt/ssd-2/mesaoptimizer/wuschel/activation_additions/activation_additions/metrics.py:135, in forward_with_funcs(model, funcs, *fwd_args, **fwd_kwargs)
#     133     if funcs is not None and funcs[0] is not None:
#     134         pre_ret = funcs[0](model)
# --> 135     return model.forward(*fwd_args, **fwd_kwargs)
#     136 finally:
#     137     if funcs is not None and funcs[1] is not None:
#
# File /mnt/ssd-2/mesaoptimizer/miniconda3/envs/wuschel_env/lib/python3.10/site-packages/transformer_lens/HookedTransformer.py:358, in HookedTransformer.forward(self, input, return_type, loss_per_token, prepend_bos, stop_at_layer, past_kv_cache)
#     353     if shortformer_pos_embed is not None:
#     354         shortformer_pos_embed = shortformer_pos_embed.to(
#     355             devices.get_device_for_block_index(i, self.cfg)
#     356         )
# --> 358     residual = block(
#     359         residual,
#     360         past_kv_cache_entry=past_kv_cache[i]
#     361         if past_kv_cache is not None
#     362         else None,  # Cache contains a list of HookedTransformerKeyValueCache objects, one for each block
#     363         shortformer_pos_embed=shortformer_pos_embed,
#     364     )  # [batch, pos, d_model]
#     366 if stop_at_layer is not None:
#     367     # When we stop at an early layer, we end here rather than doing further computation
#     368     return None
#
# File /mnt/ssd-2/mesaoptimizer/miniconda3/envs/wuschel_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /mnt/ssd-2/mesaoptimizer/miniconda3/envs/wuschel_env/lib/python3.10/site-packages/transformer_lens/components.py:893, in TransformerBlock.forward(self, resid_pre, shortformer_pos_embed, past_kv_cache_entry)
#     875 def forward(
#     876     self,
#     877     resid_pre: Float[torch.Tensor, "batch pos d_model"],
#    (...)
#     881     past_kv_cache_entry: Optional[HookedTransformerKeyValueCacheEntry] = None,
#     882 ) -> Float[torch.Tensor, "batch pos d_model"]:
#     883     """A single Transformer block.
#     884
#     885     Args:
#    (...)
#     891         _type_: _description_
#     892     """
# --> 893     resid_pre = self.hook_resid_pre(resid_pre)  # [batch, pos, d_model]
#     895     query_input = resid_pre
#     896     key_input = resid_pre
#
# File /mnt/ssd-2/mesaoptimizer/miniconda3/envs/wuschel_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1215, in Module._call_impl(self, *input, **kwargs)
#    1213 if _global_forward_hooks or self._forward_hooks:
#    1214     for hook in (*_global_forward_hooks.values(), *self._forward_hooks.values()):
# -> 1215         hook_result = hook(self, input, result)
#    1216         if hook_result is not None:
#    1217             result = hook_result
#
# File /mnt/ssd-2/mesaoptimizer/miniconda3/envs/wuschel_env/lib/python3.10/site-packages/transformer_lens/hook_points.py:67, in HookPoint.add_hook.<locals>.full_hook(module, module_input, module_output)
#      66 def full_hook(module, module_input, module_output):
# ---> 67     return hook(module_output, hook=self)
#
# TypeError: 'list' object is not callable
